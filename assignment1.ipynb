# %%
>>> a = """
   Twinkle, twinkle, little star,
            how I wonder what you are!
                    up above the world so high,
                    like a diamond in the sky.
   Twinkle, twinkle, little star,
            how I wonder what you are 

"""
>>> print(a)
# Out:
#    Twinkle, twinkle, little star,
#             how I wonder what you are!
#                     up above the world so high,
#                     like a diamond in the sky.
#    Twinkle, twinkle, little star,
#             how I wonder what you are

# %%
import platform
platform.python_version()
# Out:
# '3.9.7'

# %%
from datetime import date

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2022-01-01

# %%
from math import pi
r = float(input ("Input the radius of the circle : "))
print ("The area of the circle with radius " + str(r) + " is: " + str(pi * r**2))
# Out:
# Input the radius of the circle : 25
# The area of the circle with radius 25.0 is: 1963.4954084936207

# %%
fname = input("Input your First Name : ")
lname = input("Input your Last Name : ")
print ("Hello  " + lname + " " + fname)
# Out:
# Input your First Name : Syed Muhammad Arham
# Input your Last Name :  Sina
# Hello   Sina Syed Muhammad Arham

# %%
a=int(input("enter first number : "))

b=int(input("enter second number : "))

print("sum of",a, "and",b,"is",a+b)
# Out:
# enter first number : 7
# enter second number : 8
# sum of 7 and 8 is 15
